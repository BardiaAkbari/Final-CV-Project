# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import kagglehub
import os

path = kagglehub.dataset_download("chenxaoyu/modelnet-normal-resampled")

print("Path to dataset files:", path)

dataset_root = ""
for root, dirs, files in os.walk(path):
    if 'airplane' in dirs:
        dataset_root = root
        break

print(f"Verified Dataset Root: {dataset_root}")
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/chenxaoyu/modelnet-normal-resampled?dataset_version_number=1...
# 100%|██████████| 1.65G/1.65G [00:13<00:00, 131MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/chenxaoyu/modelnet-normal-resampled/versions/1
# Verified Dataset Root: /root/.cache/kagglehub/datasets/chenxaoyu/modelnet-normal-resampled/versions/1/modelnet40_normal_resampled

# %%
# !git clone https://github.com/BardiaAkbari/Final-CV-Project.git
# Out:
# Cloning into 'Final-CV-Project'...
# remote: Enumerating objects: 570, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 570 (delta 20), reused 24 (delta 18), pack-reused 539 (from 1)
# Receiving objects: 100% (570/570), 16.40 MiB | 20.81 MiB/s, done.
# Resolving deltas: 100% (150/150), done.

# %%
import os
import sys
import torch
import gc

torch.cuda.empty_cache()
gc.collect()

os.chdir('/content/Final-CV-Project/Code')



if 'dataset_root' not in locals():
    possible_root = "/root/.cache/kagglehub/datasets/chenxaoyu/modelnet-normal-resampled/versions/1"
    if os.path.exists(possible_root):
        dataset_root = possible_root
    else:
        dataset_root = os.path.abspath("data/modelnet40_normal_resampled")



# !mkdir -p data
# !ln -sfn "{dataset_root}" data/modelnet40_normal_resampled

command = (
  f"python train_stratifiedTransformer.py "
  f"--batch_size 16 "
  f"--epoch 150 "
  f"--lr 1e-3 "
  f"--weight_decay 1e-4 "
  f"--checkpoint_dir ./checkpoints_stratifiedTransformer "
  )

# !{command}

print(f"\n✅ FINISHED TRAINING")

torch.cuda.empty_cache()
# Out:
# Traceback (most recent call last):
#   File "/content/Final-CV-Project/Code/train_stratifiedTransformer.py", line 12, in <module>
#     from models.stratified_transformer import StratifiedCls
#   File "/content/Final-CV-Project/Code/models/stratified_transformer.py", line 5, in <module>
#     from ..torch_points3d.modules.KPConv.kernels import KPConvLayer
# ImportError: attempted relative import beyond top-level package
#
# ✅ FINISHED TRAINING
