# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import kagglehub
import os

path = kagglehub.dataset_download("chenxaoyu/modelnet-normal-resampled")

print("Path to dataset files:", path)

dataset_root = ""
for root, dirs, files in os.walk(path):
    if 'airplane' in dirs:
        dataset_root = root
        break

print(f"Verified Dataset Root: {dataset_root}")
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/chenxaoyu/modelnet-normal-resampled?dataset_version_number=1...
#  79%|███████▉  | 1.30G/1.65G [01:02<00:17, 22.0MB/s]

# %%
# !git clone https://github.com/BardiaAkbari/Final-CV-Project.git
# Out:
# fatal: destination path 'Final-CV-Project' already exists and is not an empty directory.

# %%
import os
import sys
import torch
import gc

torch.cuda.empty_cache()
gc.collect()

os.chdir('/content/Final-CV-Project/Code')



if 'dataset_root' not in locals():
    possible_root = "/root/.cache/kagglehub/datasets/chenxaoyu/modelnet-normal-resampled/versions/1"
    if os.path.exists(possible_root):
        dataset_root = possible_root
    else:
        dataset_root = os.path.abspath("data/modelnet40_normal_resampled")

print(f"\n{'='*40}")
print(f"🚀 STARTING TRAINING FOR")
print(f"{'='*40}\n")

# !mkdir -p data
# !ln -sfn "{dataset_root}" data/modelnet40_normal_resampled

command = (
  f"python train_stratifiedTransformer.py "
  f"--batch_size 16 "
  f"--epoch 150 "
  f"--lr 1e-3 "
  f"--weight_decay 1e-4 "
  f"--checkpoint_dir ./checkpoints_StratifiedTransformerCLS "
  )

# !{command}

print(f"\n✅ FINISHED TRAINING")

torch.cuda.empty_cache()
# Out:
# ========================================
# 🚀 STARTING TRAINING FOR
# ========================================
#
# Traceback (most recent call last):
#   File "/content/Final-CV-Project/Code/train_stratifiedTransformer.py", line 12, in <module>
#     from models.stratified_transformer import StratifiedCls
#   File "/content/Final-CV-Project/Code/models/stratified_transformer.py", line 5, in <module>
#     from .torch_points3d.kernels import KPConvLayer
#   File "/content/Final-CV-Project/Code/models/torch_points3d/kernels.py", line 4, in <module>
#     from .kernel_utils import kernel_point_optimization_debug, load_kernels
# ModuleNotFoundError: No module named 'models.torch_points3d.kernel_utils'
#
# ✅ FINISHED TRAINING
